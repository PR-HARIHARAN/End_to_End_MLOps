# %% [markdown]
# ##### utils

# %%
d = {"key":"value","key1":"value1"}

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"value","key1":"value1"})

# %%
d2.key
# Out:
# 'value'

# %%
def product(x:int ,y:int) -> int:
    return x*y

# %%
product(2,4)
# Out:
# 8

# %%
product(2,"4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def product(x:int ,y:int) -> int:
    return x*y

# %%
product(2,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 product(2,"4")
#
# File e:\01_Projects\02_Main\End_to_End_MLOps\.venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function product at 0x00000156CA18ACA0> does not match annotation type <class 'int'>
